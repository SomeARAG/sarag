# %% [markdown]
# This is a presentation of computing the topology of $P(X,Y)$ i.e. a graph isotopic to its zero set in the real plane.

# %%
maxima_calculus.load(' "./sarag/sarag.mac" ')

# %%
load('sage/drawTopology_code.sage')

# %%
load('sage/drawMultiCertificate_code.sage')

# %%
maxima_calculus.batch('"./tests/arag_test.mac"','test')
# Out:
# []

# %%
maxima_calculus.batch('"./tests/hard_test.mac"','test')
# Out:
# []

# %%
MAX=maxima_calculus

# %%
sage: version()
# Out:
# 'SageMath version 7.5.1, Release Date: 2017-01-15'

# %%
sage: maxima.version()
# Out:
# '5.35.1'

# %%
var('X','Y','x','y','t','a','b','c')
# Out:
# (X, Y, x, y, t, a, b, c)

# %%
  T=MAX.topology((X*Y-1)*(4*Y^2-4*X-1)*(4*Y^2+4*X-1),X,Y).sage();T
# Out:
# [1, [4, [4, 3], 6, [5, 5], 6, [5, 1], 6, [4, 2], 4]]

# %%
drawTopology(T[1])
# Out:
# Graphics object consisting of 56 graphics primitives

# %%
show(point((1,1), rgbcolor="red",size=40)+line([(0,0),(1,1)]),\
     axes=false)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
L=[0];drawTopology(L)
# Out:
# 'empty curve'

# %%
 L=[2];A=drawTopology(L)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
 L=[0,[1,1],0];A=drawTopology(L)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
L=[0,[1,1],0,[1,1],2];A=drawTopology(L)
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
T=MAX.topology(2*y^3+(3*x-3)*y^2+(3*x^2-3*x)*y+x^3,x,y).sage();T
# Out:
# [0, [1, [2, 2], 3, [2, 1], 3, [2, 2], 1]]

# %%
drawTopology(T[1])
# Out:
# Graphics object consisting of 19 graphics primitives

# %%
T=MAX.topology(x^2+y^2+1,x,y).sage();T
# Out:
# [0, [0]]

# %%
MAX.degree(y-1,x).sage()
# Out:
# 0

# %%
MAX.discriminant(y-1,y).sage()
# Out:
# 1

# %%
MAX.numberOfRoots(y-1,y).sage()
# Out:
# 1

# %%
[0,[MAX.numberOfRoots(y-1,y).sage()]]
# Out:
# [0, [1]]

# %%
T=MAX.topology(y-1,x,y).sage();T
# Out:
# [0, [1]]

# %%
MAX.degree(x*y-1,x).sage()
# Out:
# 1

# %%
l=MAX.leadCoeff(x*y-1,y).sage();l
# Out:
# x

# %%
MAX.degree(l,x).sage()
# Out:
# 1

# %%
T=MAX.topology(x*y-1,x,y).sage();T
# Out:
# [1, [2]]

# %%
T=MAX.topology((x+y)*y-1,x,y).sage();T
# Out:
# [0, [2]]

# %%
T=MAX.topology(x^2-1,x,y).sage();T
# Out:
# [1, [2]]

# %%
T=MAX.topology(x+y-1,x,y).sage();T
# Out:
# [0, [1]]

# %%
T=MAX.topology(x^2-y,x,y).sage();T
# Out:
# [0, [1]]

# %%
T=MAX.topology(x-y^2,x,y).sage();T
# Out:
# [0, [0, [1, 1], 2]]

# %%
T=MAX.topology(x^2-y^2,x,y).sage();T
# Out:
# [0, [2, [1, 1], 2]]

# %%
T=MAX.topology(x-x^2,x,y).sage();T
# Out:
# [1, [2]]

# %%
pol=MAX.ratexpand((x+y)-(x+y)^2).sage();pol
# Out:
# -x^2 - 2*x*y - y^2 + x + y

# %%
T=MAX.topology(pol,x,y).sage();T
# Out:
# [0, [2]]

# %%
T=MAX.topology(x^2-x^3*y,x,y).sage();T
# Out:
# not_squarefree

# %%
pol=MAX.ratexpand((x+y)^3-(x+y)^2).sage();pol
# Out:
# x^3 + 3*x^2*y + 3*x*y^2 + y^3 - x^2 - 2*x*y - y^2

# %%
MAX.topology(pol,x,y).sage()
# Out:
# not_squarefree

# %%
MAX.topology(y^3-y^2,x,y).sage()
# Out:
# not_squarefree

# %%
MAX.topology(1,x,y).sage()
# Out:
# []

# %%
MAX.topology(x-y^2,x,y).sage()
# Out:
# [0, [0, [1, 1], 2]]

# %%
[\"./sarag/hard_test.mac\",12,15,19,27]

# %%
MAX.topology\
(x^5-x^2*y^3+x*y^4-x^4+x*y^3-y^4+x^3+x^2*y+x*y^2-2*x^2-y^2+x,'deCasteljauIsolateRoots',x,y).sage();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-4392b624c2ed> in <module>()
# ----> 1 MAX.topology(x**Integer(5)-x**Integer(2)*y**Integer(3)+x*y**Integer(4)-x**Integer(4)+x*y**Integer(3)-y**Integer(4)+x**Integer(3)+x**Integer(2)*y+x*y**Integer(2)-Integer(2)*x**Integer(2)-y**Integer(2)+x,'deCasteljauIsolateRoots',x,y).sage();
#
# /usr/lib/sagemath/local/lib/python2.7/site-packages/sage/interfaces/interface.py in __call__(self, *args, **kwds)
#     606
#     607     def __call__(self, *args, **kwds):
# --> 608         return self._parent.function_call(self._name, list(args), kwds)
#     609
#     610     def _sage_doc_(self):
#
# /usr/lib/sagemath/local/lib/python2.7/site-packages/sage/interfaces/interface.py in function_call(self, function, args, kwds)
#     532                                        [s.name() for s in args],
# ...

# %%
MAX.topology(15/4 + 8*x - 16*x^2 + 8*y - 112*x*y + 128*x^2*y \
         - 16*y^2 +128*x*y^2 - 128*x^2*y^2,x,y).sage();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-6fc8449a973a> in <module>()
# ----> 1 MAX.topology(Integer(15)/Integer(4) + Integer(8)*x - Integer(16)*x**Integer(2) + Integer(8)*y - Integer(112)*x*y + Integer(128)*x**Integer(2)*y          - Integer(16)*y**Integer(2) +Integer(128)*x*y**Integer(2) - Integer(128)*x**Integer(2)*y**Integer(2),x,y).sage();
#
# /usr/lib/sagemath/local/lib/python2.7/site-packages/sage/interfaces/interface.py in __call__(self, *args, **kwds)
#     606
#     607     def __call__(self, *args, **kwds):
# --> 608         return self._parent.function_call(self._name, list(args), kwds)
#     609
#     610     def _sage_doc_(self):
#
# /usr/lib/sagemath/local/lib/python2.7/site-packages/sage/interfaces/interface.py in function_call(self, function, args, kwds)
#     532                                        [s.name() for s in args],
# ...

# %%
MAX.topology( 55/256 - x + 2*x^2 - 2*x^3 + x^4 - 55/64*y \
+ 2*x*y - 2*x^2*y +119/64*y^2 - 2*x*y^2 + 2*x^2*y^2 - 2*y^3 + y^4,x,y)\
.sage()
# Out:
# [1, [0, [1, 1], 2, [3, 1], 4, [3, 2], 4, [3, 3], 2, [1, 1], 0]]

# %%
MAX.leadCoeff(55/256 - x + 2*x^2 - 2*x^3 + x^4 - 55/64*y \
+ 2*x*y - 2*x^2*y +119/64*y^2 - 2*x*y^2 + 2*x^2*y^2 - 2*y^3 + y^4,y).sage()
# Out:
# 1

# %%
MAX.leadCoeff(15/4 + 8*x - 16*x^2 + 8*y - 112*x*y + 128*x^2*y \
         - 16*y^2 +128*x*y^2 - 128*x^2*y^2,y).\
sage()
# Out:
# -128*x^2 + 128*x - 16

# %%
Q=MAX.subst(x+y,x,15/4 + 8*x - 16*x^2 + 8*y - 112*x*y + 128*x^2*y \
         - 16*y^2 +128*x*y^2 - 128*x^2*y^2).\
sage();Q
# Out:
# -128*(x + y)^2*y^2 + 128*(x + y)^2*y + 128*(x + y)*y^2 - 16*(x + y)^2 - 112*(x + y)*y - 16*y^2 + 8*x + 16*y + 15/4

# %%
MAX.topology(Q,x,y).sage()
# Out:
# [0, [4, [3, 2], 2, [3, 2], 4, [3, 2], 2, [3, 2], 4]]
